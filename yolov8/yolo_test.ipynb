# %% [markdown]
# <a href="https://colab.research.google.com/github/maikelele/traffic-sign-recognition/blob/dataset/yolo_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics==8.0.196
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.9/78.2 GB disk)

# %%
# !yolo task=detect mode=predict model=best.pt  conf=0.25 source='kazimierz.mp4'
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11133711 parameters, 0 gradients, 28.5 GFLOPs
#
# video 1/1 (1/5182) /content/drive/MyDrive/YOLO_Training/to_check/kazimierz.mp4: 384x640 (no detections), 90.3ms
# video 1/1 (2/5182) /content/drive/MyDrive/YOLO_Training/to_check/kazimierz.mp4: 384x640 (no detections), 10.7ms
# video 1/1 (3/5182) /content/drive/MyDrive/YOLO_Training/to_check/kazimierz.mp4: 384x640 (no detections), 10.7ms
# video 1/1 (4/5182) /content/drive/MyDrive/YOLO_Training/to_check/kazimierz.mp4: 384x640 (no detections), 10.7ms
# video 1/1 (5/5182) /content/drive/MyDrive/YOLO_Training/to_check/kazimierz.mp4: 384x640 (no detections), 10.6ms
# video 1/1 (6/5182) /content/drive/MyDrive/YOLO_Training/to_check/kazimierz.mp4: 384x640 (no detections), 10.7ms
# video 1/1 (7/5182) /content/drive/MyDrive/YOLO_Training/to_check/kazimierz.mp4: 384x640 (no detections), 10.7ms
# ...
