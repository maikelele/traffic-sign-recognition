# %% [markdown]
# <a href="https://colab.research.google.com/github/maikelele/traffic-sign-recognition/blob/label-studio/yolov8_pretrained.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#necessary imports
import os
import glob
from IPython.display import Image, display

# %%
#gpu access
# !nvidia-smi --query-gpu=gpu_name,driver_version,temperature.gpu,utilization.gpu,utilization.memory --format=csv
# Out:
# name, driver_version, temperature.gpu, utilization.gpu [%], utilization.memory [%]
# Tesla T4, 535.104.05, 39, 0 %, 0 %

# %%
#home variable
HOME= os.getcwd()
print(HOME)
# Out:
# /content

# %%
#installing yolov8
#!pip install ultralytics==8.0.0
# !pip install ultralytics==8.0.196

# %%
#checking yolov8
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.3/78.2 GB disk)

# %%
#importing the dataset
#!mkdir {HOME}/datasets
# %cd {HOME}/datasets
# Out:
# /content/datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="J1WZ9Alz86gSqL19G0sk")
project = rf.workspace("roboflow-100").project("road-signs-6ih4y")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
#training
# %cd {HOME}
# !yolo task=detect mode=train model=yolov8s.pt data=/content/datasets/road_signs/data.yaml epochs=100 imgsz=640
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.2.21 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !cp -r /content/runs /content/drive/MyDrive/YOLO_Training/

# %%
# !cp -r /content/datasets /content/drive/MyDrive/YOLO_Training/

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train7/weights/best.pt  conf=0.25 source='/content/drive/MyDrive/YOLO_Training/to_check/kazimierz.mp4'
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (186/5182) /content/drive/MyDrive/YOLO_Training/to_check/kazimierz.mp4: 384x640 (no detections), 10.8ms
# video 1/1 (187/5182) /content/drive/MyDrive/YOLO_Training/to_check/kazimierz.mp4: 384x640 (no detections), 10.8ms
# video 1/1 (188/5182) /content/drive/MyDrive/YOLO_Training/to_check/kazimierz.mp4: 384x640 (no detections), 10.8ms
# video 1/1 (189/5182) /content/drive/MyDrive/YOLO_Training/to_check/kazimierz.mp4: 384x640 (no detections), 10.7ms
# video 1/1 (190/5182) /content/drive/MyDrive/YOLO_Training/to_check/kazimierz.mp4: 384x640 (no detections), 10.7ms
# video 1/1 (191/5182) /content/drive/MyDrive/YOLO_Training/to_check/kazimierz.mp4: 384x640 (no detections), 11.2ms
# video 1/1 (192/5182) /content/drive/MyDrive/YOLO_Training/to_check/kazimierz.mp4: 384x640 1 red_light, 12.2ms
# video 1/1 (193/5182) /content/drive/MyDrive/YOLO_Training/to_check/kazimierz.mp4: 384x640 (no detections), 11.0ms
# ...

# %%
# !cp /content/runs/detect/predict/kazimierz.avi /content/drive/MyDrive/YOLO_Training/
