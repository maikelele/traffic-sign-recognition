# %% [markdown]
# <a href="https://colab.research.google.com/github/maikelele/traffic-sign-recognition/blob/dataset/yolov5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def conv_block(x, filters, kernel_size, strides=1, activation=True):
    x = layers.Conv2D(filters, kernel_size, strides=strides, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    if activation:
        x = layers.LeakyReLU(alpha=0.1)(x)
    return x

def residual_block(x, filters):
    shortcut = x
    x = conv_block(x, filters // 2, 1)
    x = conv_block(x, filters, 3)
    x = layers.Add()([shortcut, x])
    return x

def csp_block(x, filters, num_blocks):
    x = conv_block(x, filters, 3, strides=2)
    route = x
    route = conv_block(route, filters // 2, 1)

    x = conv_block(x, filters // 2, 1)
    for _ in range(num_blocks):
        x = residual_block(x, filters // 2)

    x = conv_block(x, filters // 2, 1)
    x = layers.Concatenate()([x, route])
    x = conv_block(x, filters, 1)
    return x

def create_panet(features):
    f3, f4, f5 = features
    p5 = conv_block(f5, 256, 1)
    p5 = layers.UpSampling2D(2)(p5)
    p4 = layers.Concatenate()([p5, f4])
    p4 = conv_block(p4, 256, 1)
    p4 = layers.UpSampling2D(2)(p4)
    p3 = layers.Concatenate()([p4, f3])
    p3 = conv_block(p3, 256, 1)
    return p3, p4, p5

def yolo_head(x, num_classes):
    x = conv_block(x, 512, 3)
    x = conv_block(x, 3 * (num_classes + 5), 1, activation=False)
    return x

def create_yolov5(input_shape, num_classes):
    inputs = layers.Input(input_shape)
    x = conv_block(inputs, 32, 3)

    x = csp_block(x, 64, 1)
    x = csp_block(x, 128, 2)
    x = csp_block(x, 256, 8)
    f3 = x
    x = csp_block(x, 512, 8)
    f4 = x
    x = csp_block(x, 1024, 4)
    f5 = x

    features = create_panet([f3, f4, f5])

    yolo_outputs = [yolo_head(feature, num_classes) for feature in features]

    model = models.Model(inputs, yolo_outputs)
    return model

input_shape = (640, 640, 3)
num_classes = 264
model = create_yolov5(input_shape, num_classes)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 640, 640, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 640, 640, 32)         864       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 640, 640, 32)         128       ['conv2d[0][0]']
#  Normalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 640, 640, 32)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 320, 320, 64)         18432     ['leaky_re_lu[0][0]']
#
#  batch_normalization_1 (Bat  (None, 320, 320, 64)         256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 320, 320, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 320, 320, 32)         2048      ['leaky_re_lu_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 320, 320, 32)         128       ['conv2d_3[0][0]']
#  chNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 320, 320, 32)         0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 320, 320, 16)         512       ['leaky_re_lu_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 320, 320, 16)         64        ['conv2d_4[0][0]']
#  chNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 320, 320, 16)         0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 320, 320, 32)         4608      ['leaky_re_lu_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 320, 320, 32)         128       ['conv2d_5[0][0]']
#  chNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 320, 320, 32)         0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  add (Add)                   (None, 320, 320, 32)         0         ['leaky_re_lu_3[0][0]',
#                                                                      'leaky_re_lu_5[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 320, 320, 32)         1024      ['add[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 320, 320, 32)         2048      ['leaky_re_lu_1[0][0]']
#
#  batch_normalization_6 (Bat  (None, 320, 320, 32)         128       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_2 (Bat  (None, 320, 320, 32)         128       ['conv2d_2[0][0]']
#  chNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 320, 320, 32)         0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 320, 320, 32)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  concatenate (Concatenate)   (None, 320, 320, 64)         0         ['leaky_re_lu_6[0][0]',
#                                                                      'leaky_re_lu_2[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 320, 320, 64)         4096      ['concatenate[0][0]']
#
#  batch_normalization_7 (Bat  (None, 320, 320, 64)         256       ['conv2d_7[0][0]']
#  chNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 320, 320, 64)         0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_8 (Conv2D)           (None, 160, 160, 128)        73728     ['leaky_re_lu_7[0][0]']
#
#  batch_normalization_8 (Bat  (None, 160, 160, 128)        512       ['conv2d_8[0][0]']
#  chNormalization)
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 160, 160, 128)        0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_10 (Conv2D)          (None, 160, 160, 64)         8192      ['leaky_re_lu_8[0][0]']
#
#  batch_normalization_10 (Ba  (None, 160, 160, 64)         256       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 160, 160, 64)         0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 160, 160, 32)         2048      ['leaky_re_lu_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 160, 160, 32)         128       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 160, 160, 32)         0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 160, 160, 64)         18432     ['leaky_re_lu_11[0][0]']
#
#  batch_normalization_12 (Ba  (None, 160, 160, 64)         256       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 160, 160, 64)         0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  add_1 (Add)                 (None, 160, 160, 64)         0         ['leaky_re_lu_10[0][0]',
#                                                                      'leaky_re_lu_12[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 160, 160, 32)         2048      ['add_1[0][0]']
#
#  batch_normalization_13 (Ba  (None, 160, 160, 32)         128       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 160, 160, 32)         0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 160, 160, 64)         18432     ['leaky_re_lu_13[0][0]']
#
#  batch_normalization_14 (Ba  (None, 160, 160, 64)         256       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 160, 160, 64)         0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  add_2 (Add)                 (None, 160, 160, 64)         0         ['add_1[0][0]',
#                                                                      'leaky_re_lu_14[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 160, 160, 64)         4096      ['add_2[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 160, 160, 64)         8192      ['leaky_re_lu_8[0][0]']
#
#  batch_normalization_15 (Ba  (None, 160, 160, 64)         256       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_9 (Bat  (None, 160, 160, 64)         256       ['conv2d_9[0][0]']
#  chNormalization)
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 160, 160, 64)         0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 160, 160, 64)         0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  concatenate_1 (Concatenate  (None, 160, 160, 128)        0         ['leaky_re_lu_15[0][0]',
#  )                                                                   'leaky_re_lu_9[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 160, 160, 128)        16384     ['concatenate_1[0][0]']
#
#  batch_normalization_16 (Ba  (None, 160, 160, 128)        512       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 160, 160, 128)        0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 80, 80, 256)          294912    ['leaky_re_lu_16[0][0]']
#
#  batch_normalization_17 (Ba  (None, 80, 80, 256)          1024      ['conv2d_17[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 80, 80, 256)          0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 80, 80, 128)          32768     ['leaky_re_lu_17[0][0]']
#
#  batch_normalization_19 (Ba  (None, 80, 80, 128)          512       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 80, 80, 128)          0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 80, 80, 64)           8192      ['leaky_re_lu_19[0][0]']
#
#  batch_normalization_20 (Ba  (None, 80, 80, 64)           256       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 80, 80, 64)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_21 (Conv2D)          (None, 80, 80, 128)          73728     ['leaky_re_lu_20[0][0]']
#
#  batch_normalization_21 (Ba  (None, 80, 80, 128)          512       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 80, 80, 128)          0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  add_3 (Add)                 (None, 80, 80, 128)          0         ['leaky_re_lu_19[0][0]',
#                                                                      'leaky_re_lu_21[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 80, 80, 64)           8192      ['add_3[0][0]']
#
#  batch_normalization_22 (Ba  (None, 80, 80, 64)           256       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_22 (LeakyReLU)  (None, 80, 80, 64)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 80, 80, 128)          73728     ['leaky_re_lu_22[0][0]']
#
#  batch_normalization_23 (Ba  (None, 80, 80, 128)          512       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_23 (LeakyReLU)  (None, 80, 80, 128)          0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  add_4 (Add)                 (None, 80, 80, 128)          0         ['add_3[0][0]',
#                                                                      'leaky_re_lu_23[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 80, 80, 64)           8192      ['add_4[0][0]']
#
#  batch_normalization_24 (Ba  (None, 80, 80, 64)           256       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_24 (LeakyReLU)  (None, 80, 80, 64)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 80, 80, 128)          73728     ['leaky_re_lu_24[0][0]']
#
#  batch_normalization_25 (Ba  (None, 80, 80, 128)          512       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_25 (LeakyReLU)  (None, 80, 80, 128)          0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  add_5 (Add)                 (None, 80, 80, 128)          0         ['add_4[0][0]',
#                                                                      'leaky_re_lu_25[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 80, 80, 64)           8192      ['add_5[0][0]']
#
#  batch_normalization_26 (Ba  (None, 80, 80, 64)           256       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_26 (LeakyReLU)  (None, 80, 80, 64)           0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_27 (Conv2D)          (None, 80, 80, 128)          73728     ['leaky_re_lu_26[0][0]']
#
#  batch_normalization_27 (Ba  (None, 80, 80, 128)          512       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_27 (LeakyReLU)  (None, 80, 80, 128)          0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  add_6 (Add)                 (None, 80, 80, 128)          0         ['add_5[0][0]',
#                                                                      'leaky_re_lu_27[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 80, 80, 64)           8192      ['add_6[0][0]']
#
#  batch_normalization_28 (Ba  (None, 80, 80, 64)           256       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_28 (LeakyReLU)  (None, 80, 80, 64)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 80, 80, 128)          73728     ['leaky_re_lu_28[0][0]']
#
#  batch_normalization_29 (Ba  (None, 80, 80, 128)          512       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_29 (LeakyReLU)  (None, 80, 80, 128)          0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  add_7 (Add)                 (None, 80, 80, 128)          0         ['add_6[0][0]',
#                                                                      'leaky_re_lu_29[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 80, 80, 64)           8192      ['add_7[0][0]']
#
#  batch_normalization_30 (Ba  (None, 80, 80, 64)           256       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_30 (LeakyReLU)  (None, 80, 80, 64)           0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 80, 80, 128)          73728     ['leaky_re_lu_30[0][0]']
#
#  batch_normalization_31 (Ba  (None, 80, 80, 128)          512       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_31 (LeakyReLU)  (None, 80, 80, 128)          0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  add_8 (Add)                 (None, 80, 80, 128)          0         ['add_7[0][0]',
#                                                                      'leaky_re_lu_31[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 80, 80, 64)           8192      ['add_8[0][0]']
#
#  batch_normalization_32 (Ba  (None, 80, 80, 64)           256       ['conv2d_32[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_32 (LeakyReLU)  (None, 80, 80, 64)           0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_33 (Conv2D)          (None, 80, 80, 128)          73728     ['leaky_re_lu_32[0][0]']
#
#  batch_normalization_33 (Ba  (None, 80, 80, 128)          512       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_33 (LeakyReLU)  (None, 80, 80, 128)          0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  add_9 (Add)                 (None, 80, 80, 128)          0         ['add_8[0][0]',
#                                                                      'leaky_re_lu_33[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 80, 80, 64)           8192      ['add_9[0][0]']
#
#  batch_normalization_34 (Ba  (None, 80, 80, 64)           256       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_34 (LeakyReLU)  (None, 80, 80, 64)           0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 80, 80, 128)          73728     ['leaky_re_lu_34[0][0]']
#
#  batch_normalization_35 (Ba  (None, 80, 80, 128)          512       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_35 (LeakyReLU)  (None, 80, 80, 128)          0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  add_10 (Add)                (None, 80, 80, 128)          0         ['add_9[0][0]',
#                                                                      'leaky_re_lu_35[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 80, 80, 128)          16384     ['add_10[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 80, 80, 128)          32768     ['leaky_re_lu_17[0][0]']
#
#  batch_normalization_36 (Ba  (None, 80, 80, 128)          512       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 80, 80, 128)          512       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_36 (LeakyReLU)  (None, 80, 80, 128)          0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 80, 80, 128)          0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  concatenate_2 (Concatenate  (None, 80, 80, 256)          0         ['leaky_re_lu_36[0][0]',
#  )                                                                   'leaky_re_lu_18[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 80, 80, 256)          65536     ['concatenate_2[0][0]']
#
#  batch_normalization_37 (Ba  (None, 80, 80, 256)          1024      ['conv2d_37[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_37 (LeakyReLU)  (None, 80, 80, 256)          0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  conv2d_38 (Conv2D)          (None, 40, 40, 512)          1179648   ['leaky_re_lu_37[0][0]']
#
#  batch_normalization_38 (Ba  (None, 40, 40, 512)          2048      ['conv2d_38[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_38 (LeakyReLU)  (None, 40, 40, 512)          0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_40 (Conv2D)          (None, 40, 40, 256)          131072    ['leaky_re_lu_38[0][0]']
#
#  batch_normalization_40 (Ba  (None, 40, 40, 256)          1024      ['conv2d_40[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_40 (LeakyReLU)  (None, 40, 40, 256)          0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 40, 40, 128)          32768     ['leaky_re_lu_40[0][0]']
#
#  batch_normalization_41 (Ba  (None, 40, 40, 128)          512       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_41 (LeakyReLU)  (None, 40, 40, 128)          0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 40, 40, 256)          294912    ['leaky_re_lu_41[0][0]']
#
#  batch_normalization_42 (Ba  (None, 40, 40, 256)          1024      ['conv2d_42[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_42 (LeakyReLU)  (None, 40, 40, 256)          0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  add_11 (Add)                (None, 40, 40, 256)          0         ['leaky_re_lu_40[0][0]',
#                                                                      'leaky_re_lu_42[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 40, 40, 128)          32768     ['add_11[0][0]']
#
#  batch_normalization_43 (Ba  (None, 40, 40, 128)          512       ['conv2d_43[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_43 (LeakyReLU)  (None, 40, 40, 128)          0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  conv2d_44 (Conv2D)          (None, 40, 40, 256)          294912    ['leaky_re_lu_43[0][0]']
#
#  batch_normalization_44 (Ba  (None, 40, 40, 256)          1024      ['conv2d_44[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_44 (LeakyReLU)  (None, 40, 40, 256)          0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  add_12 (Add)                (None, 40, 40, 256)          0         ['add_11[0][0]',
#                                                                      'leaky_re_lu_44[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 40, 40, 128)          32768     ['add_12[0][0]']
#
#  batch_normalization_45 (Ba  (None, 40, 40, 128)          512       ['conv2d_45[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_45 (LeakyReLU)  (None, 40, 40, 128)          0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_46 (Conv2D)          (None, 40, 40, 256)          294912    ['leaky_re_lu_45[0][0]']
#
#  batch_normalization_46 (Ba  (None, 40, 40, 256)          1024      ['conv2d_46[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_46 (LeakyReLU)  (None, 40, 40, 256)          0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  add_13 (Add)                (None, 40, 40, 256)          0         ['add_12[0][0]',
#                                                                      'leaky_re_lu_46[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 40, 40, 128)          32768     ['add_13[0][0]']
#
#  batch_normalization_47 (Ba  (None, 40, 40, 128)          512       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_47 (LeakyReLU)  (None, 40, 40, 128)          0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 40, 40, 256)          294912    ['leaky_re_lu_47[0][0]']
#
#  batch_normalization_48 (Ba  (None, 40, 40, 256)          1024      ['conv2d_48[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_48 (LeakyReLU)  (None, 40, 40, 256)          0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  add_14 (Add)                (None, 40, 40, 256)          0         ['add_13[0][0]',
#                                                                      'leaky_re_lu_48[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 40, 40, 128)          32768     ['add_14[0][0]']
#
#  batch_normalization_49 (Ba  (None, 40, 40, 128)          512       ['conv2d_49[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_49 (LeakyReLU)  (None, 40, 40, 128)          0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  conv2d_50 (Conv2D)          (None, 40, 40, 256)          294912    ['leaky_re_lu_49[0][0]']
#
#  batch_normalization_50 (Ba  (None, 40, 40, 256)          1024      ['conv2d_50[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_50 (LeakyReLU)  (None, 40, 40, 256)          0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  add_15 (Add)                (None, 40, 40, 256)          0         ['add_14[0][0]',
#                                                                      'leaky_re_lu_50[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 40, 40, 128)          32768     ['add_15[0][0]']
#
#  batch_normalization_51 (Ba  (None, 40, 40, 128)          512       ['conv2d_51[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_51 (LeakyReLU)  (None, 40, 40, 128)          0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  conv2d_52 (Conv2D)          (None, 40, 40, 256)          294912    ['leaky_re_lu_51[0][0]']
#
#  batch_normalization_52 (Ba  (None, 40, 40, 256)          1024      ['conv2d_52[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_52 (LeakyReLU)  (None, 40, 40, 256)          0         ['batch_normalization_52[0][0]
#                                                                     ']
#
#  add_16 (Add)                (None, 40, 40, 256)          0         ['add_15[0][0]',
#                                                                      'leaky_re_lu_52[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 40, 40, 128)          32768     ['add_16[0][0]']
#
#  batch_normalization_53 (Ba  (None, 40, 40, 128)          512       ['conv2d_53[0][0]']
#  tchNormalization)
# ...
#
#  batch_normalization_64 (Ba  (None, 20, 20, 256)          1024      ['conv2d_64[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_64 (LeakyReLU)  (None, 20, 20, 256)          0         ['batch_normalization_64[0][0]
#                                                                     ']
#
#  conv2d_65 (Conv2D)          (None, 20, 20, 512)          1179648   ['leaky_re_lu_64[0][0]']
#
#  batch_normalization_65 (Ba  (None, 20, 20, 512)          2048      ['conv2d_65[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_65 (LeakyReLU)  (None, 20, 20, 512)          0         ['batch_normalization_65[0][0]
#                                                                     ']
#
#  add_20 (Add)                (None, 20, 20, 512)          0         ['add_19[0][0]',
#                                                                      'leaky_re_lu_65[0][0]']
#
#  conv2d_66 (Conv2D)          (None, 20, 20, 256)          131072    ['add_20[0][0]']
#
#  batch_normalization_66 (Ba  (None, 20, 20, 256)          1024      ['conv2d_66[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_66 (LeakyReLU)  (None, 20, 20, 256)          0         ['batch_normalization_66[0][0]
#                                                                     ']
#
#  conv2d_67 (Conv2D)          (None, 20, 20, 512)          1179648   ['leaky_re_lu_66[0][0]']
#
#  batch_normalization_67 (Ba  (None, 20, 20, 512)          2048      ['conv2d_67[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_67 (LeakyReLU)  (None, 20, 20, 512)          0         ['batch_normalization_67[0][0]
#                                                                     ']
#
#  add_21 (Add)                (None, 20, 20, 512)          0         ['add_20[0][0]',
#                                                                      'leaky_re_lu_67[0][0]']
#
#  conv2d_68 (Conv2D)          (None, 20, 20, 256)          131072    ['add_21[0][0]']
#
#  batch_normalization_68 (Ba  (None, 20, 20, 256)          1024      ['conv2d_68[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_68 (LeakyReLU)  (None, 20, 20, 256)          0         ['batch_normalization_68[0][0]
#                                                                     ']
#
#  conv2d_69 (Conv2D)          (None, 20, 20, 512)          1179648   ['leaky_re_lu_68[0][0]']
#
#  batch_normalization_69 (Ba  (None, 20, 20, 512)          2048      ['conv2d_69[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_69 (LeakyReLU)  (None, 20, 20, 512)          0         ['batch_normalization_69[0][0]
#                                                                     ']
#
#  add_22 (Add)                (None, 20, 20, 512)          0         ['add_21[0][0]',
#                                                                      'leaky_re_lu_69[0][0]']
#
#  conv2d_70 (Conv2D)          (None, 20, 20, 512)          262144    ['add_22[0][0]']
#
#  conv2d_60 (Conv2D)          (None, 20, 20, 512)          524288    ['leaky_re_lu_59[0][0]']
#
#  batch_normalization_70 (Ba  (None, 20, 20, 512)          2048      ['conv2d_70[0][0]']
#  tchNormalization)
#
#  batch_normalization_60 (Ba  (None, 20, 20, 512)          2048      ['conv2d_60[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_70 (LeakyReLU)  (None, 20, 20, 512)          0         ['batch_normalization_70[0][0]
#                                                                     ']
#
#  leaky_re_lu_60 (LeakyReLU)  (None, 20, 20, 512)          0         ['batch_normalization_60[0][0]
#                                                                     ']
#
#  concatenate_4 (Concatenate  (None, 20, 20, 1024)         0         ['leaky_re_lu_70[0][0]',
#  )                                                                   'leaky_re_lu_60[0][0]']
#
#  conv2d_71 (Conv2D)          (None, 20, 20, 1024)         1048576   ['concatenate_4[0][0]']
#
#  batch_normalization_71 (Ba  (None, 20, 20, 1024)         4096      ['conv2d_71[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_71 (LeakyReLU)  (None, 20, 20, 1024)         0         ['batch_normalization_71[0][0]
#                                                                     ']
#
#  conv2d_72 (Conv2D)          (None, 20, 20, 256)          262144    ['leaky_re_lu_71[0][0]']
#
#  batch_normalization_72 (Ba  (None, 20, 20, 256)          1024      ['conv2d_72[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_72 (LeakyReLU)  (None, 20, 20, 256)          0         ['batch_normalization_72[0][0]
#                                                                     ']
#
#  up_sampling2d (UpSampling2  (None, 40, 40, 256)          0         ['leaky_re_lu_72[0][0]']
#  D)
#
#  concatenate_5 (Concatenate  (None, 40, 40, 768)          0         ['up_sampling2d[0][0]',
#  )                                                                   'leaky_re_lu_58[0][0]']
#
#  conv2d_73 (Conv2D)          (None, 40, 40, 256)          196608    ['concatenate_5[0][0]']
#
#  batch_normalization_73 (Ba  (None, 40, 40, 256)          1024      ['conv2d_73[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_73 (LeakyReLU)  (None, 40, 40, 256)          0         ['batch_normalization_73[0][0]
#                                                                     ']
#
#  up_sampling2d_1 (UpSamplin  (None, 80, 80, 256)          0         ['leaky_re_lu_73[0][0]']
#  g2D)
#
#  concatenate_6 (Concatenate  (None, 80, 80, 512)          0         ['up_sampling2d_1[0][0]',
#  )                                                                   'leaky_re_lu_37[0][0]']
#
#  conv2d_74 (Conv2D)          (None, 80, 80, 256)          131072    ['concatenate_6[0][0]']
#
#  batch_normalization_74 (Ba  (None, 80, 80, 256)          1024      ['conv2d_74[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_74 (LeakyReLU)  (None, 80, 80, 256)          0         ['batch_normalization_74[0][0]
#                                                                     ']
#
#  conv2d_75 (Conv2D)          (None, 80, 80, 512)          1179648   ['leaky_re_lu_74[0][0]']
#
#  conv2d_77 (Conv2D)          (None, 80, 80, 512)          1179648   ['up_sampling2d_1[0][0]']
#
#  conv2d_79 (Conv2D)          (None, 40, 40, 512)          1179648   ['up_sampling2d[0][0]']
#
#  batch_normalization_75 (Ba  (None, 80, 80, 512)          2048      ['conv2d_75[0][0]']
#  tchNormalization)
#
#  batch_normalization_77 (Ba  (None, 80, 80, 512)          2048      ['conv2d_77[0][0]']
#  tchNormalization)
#
#  batch_normalization_79 (Ba  (None, 40, 40, 512)          2048      ['conv2d_79[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_75 (LeakyReLU)  (None, 80, 80, 512)          0         ['batch_normalization_75[0][0]
#                                                                     ']
#
#  leaky_re_lu_76 (LeakyReLU)  (None, 80, 80, 512)          0         ['batch_normalization_77[0][0]
#                                                                     ']
#
#  leaky_re_lu_77 (LeakyReLU)  (None, 40, 40, 512)          0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  conv2d_76 (Conv2D)          (None, 80, 80, 807)          413184    ['leaky_re_lu_75[0][0]']
#
#  conv2d_78 (Conv2D)          (None, 80, 80, 807)          413184    ['leaky_re_lu_76[0][0]']
#
#  conv2d_80 (Conv2D)          (None, 40, 40, 807)          413184    ['leaky_re_lu_77[0][0]']
#
#  batch_normalization_76 (Ba  (None, 80, 80, 807)          3228      ['conv2d_76[0][0]']
#  tchNormalization)
#
#  batch_normalization_78 (Ba  (None, 80, 80, 807)          3228      ['conv2d_78[0][0]']
#  tchNormalization)
#
#  batch_normalization_80 (Ba  (None, 40, 40, 807)          3228      ['conv2d_80[0][0]']
#  tchNormalization)
#
# ==================================================================================================
# Total params: 23441396 (89.42 MB)
# Trainable params: 23402154 (89.27 MB)
# Non-trainable params: 39242 (153.29 KB)
# __________________________________________________________________________________________________

# %%
import glob

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="J1WZ9Alz86gSqL19G0sk")
project = rf.workspace("google-8fa6i").project("trafficsignrecognition-s1x6u")
version = project.version(2)
dataset = version.download("yolov5")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.10/dist-packages (1.1.29)
# Requirement already satisfied: certifi==2023.7.22 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2023.7.22)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.25.2)
# Requirement already satisfied: opencv-python-headless==4.8.0.74 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.8.0.74)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.4)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.4.27)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.51.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# loading Roboflow workspace...
# loading Roboflow project...

# %%
def load_image_and_labels(image_path, label_path, max_labels=50):
    # Read and process the image
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [640, 640])
    image = image / 255.0  # Normalize to [0, 1]

    # Read the label file and convert it into a tensor of shape [num_labels, 5]
    labels = tf.io.read_file(label_path)
    labels = tf.strings.split(labels, sep='\n')
    labels = tf.strings.split(labels, sep=' ')
    labels = tf.ragged.constant([tf.strings.to_number(label, tf.float32) for label in labels if tf.strings.length(label) > 0])
    labels = labels.to_tensor(shape=[max_labels, 5])

    return image, labels


def prepare_dataset(image_paths, label_paths, batch_size, max_labels=50):
    dataset = tf.data.Dataset.from_tensor_slices((image_paths, label_paths))
    dataset = dataset.map(lambda x, y: load_image_and_labels(x, y, max_labels), num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.shuffle(buffer_size=1024).batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return dataset


def get_file_paths(directory, pattern="*.jpg"):
    """Retrieve file paths based on the given pattern."""
    return glob.glob(f"{directory}/{pattern}")

# Define directories
image_directory = "/content/Trafficsignrecognition-2/train/images"
label_directory = "/content/Trafficsignrecognition-2/train/labels"

# Get lists of image and label paths
train_image_paths = get_file_paths(image_directory, pattern="*.jpg")
train_label_paths = get_file_paths(label_directory, pattern="*.txt")
train_image_paths.sort()
train_label_paths.sort()

batch_size = 4
train_dataset = prepare_dataset(train_image_paths, train_label_paths, batch_size)
# Out:
# ---------------------------------------------------------------------------
# OperatorNotAllowedInGraphError            Traceback (most recent call last)
# <ipython-input-17-da79428a88dd> in <cell line: 40>()
#      38
#      39 batch_size = 4
# ---> 40 train_dataset = prepare_dataset(train_image_paths, train_label_paths, batch_size)
#
# <ipython-input-17-da79428a88dd> in prepare_dataset(image_paths, label_paths, batch_size, max_labels)
#      18 def prepare_dataset(image_paths, label_paths, batch_size, max_labels=50):
#      19     dataset = tf.data.Dataset.from_tensor_slices((image_paths, label_paths))
# ---> 20     dataset = dataset.map(lambda x, y: load_image_and_labels(x, y, max_labels), num_parallel_calls=tf.data.AUTOTUNE)
#      21     dataset = dataset.shuffle(buffer_size=1024).batch(batch_size).prefetch(tf.data.AUTOTUNE)
#      22     return dataset
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/dataset_ops.py in map(self, map_func, num_parallel_calls, deterministic, name)
#    2278     # pylint: disable=g-import-not-at-top,protected-access
#    2279     from tensorflow.python.data.ops import map_op
# -> 2280     return map_op._map_v2(
#    2281         self,
#    2282         map_func,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/map_op.py in _map_v2(input_dataset, map_func, num_parallel_calls, deterministic, name)
#      38         input_dataset, map_func, preserve_cardinality=True, name=name)
#      39   else:
# ---> 40     return _ParallelMapDataset(
#      41         input_dataset,
#      42         map_func,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/map_op.py in __init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#     146     self._input_dataset = input_dataset
#     147     self._use_inter_op_parallelism = use_inter_op_parallelism
# --> 148     self._map_func = structured_function.StructuredFunctionWrapper(
#     149         map_func,
#     150         self._transformation_name(),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     263         fn_factory = trace_tf_function(defun_kwargs)
#     264
# --> 265     self._function = fn_factory()
#     266     # There is no graph to add in eager mode.
#     267     add_to_graph &= not context.executing_eagerly()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in get_concrete_function(self, *args, **kwargs)
#    1225   def get_concrete_function(self, *args, **kwargs):
#    1226     # Implements PolymorphicFunction.get_concrete_function.
# -> 1227     concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1228     concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1229     return concrete
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1195       if self._variable_creation_config is None:
#    1196         initializers = []
# -> 1197         self._initialize(args, kwargs, add_initializers_to=initializers)
#    1198         self._initialize_uninitialized_variables(initializers)
#    1199
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _initialize(self, args, kwds, add_initializers_to)
#     693     )
#     694     # Force the definition of the function for these arguments
# --> 695     self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     696         args, kwds, self._variable_creation_config
#     697     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in trace_function(args, kwargs, tracing_options)
#     176       kwargs = {}
#     177
# --> 178     concrete_function = _maybe_define_function(
#     179         args, kwargs, tracing_options
#     180     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _maybe_define_function(args, kwargs, tracing_options)
#     281         else:
#     282           target_func_type = lookup_func_type
# --> 283         concrete_function = _create_concrete_function(
#     284             target_func_type, lookup_func_context, func_graph, tracing_options
#     285         )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     308       attributes_lib.DISABLE_ACD, False
#     309   )
# --> 310   traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311       tracing_options.name,
#     312       tracing_options.python_function,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1057
#    1058     _, original_func = tf_decorator.unwrap(python_func)
# -> 1059     func_outputs = python_func(*func_args, **func_kwargs)
#    1060
#    1061     # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in wrapped_fn(*args, **kwds)
#     596         # the function a weak reference to itself to avoid a reference cycle.
#     597         with OptionalXlaContext(compile_with_xla):
# --> 598           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     599         return out
#     600
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py in wrapped_fn(*args)
#     229       # Note: wrapper_helper will apply autograph based on context.
#     230       def wrapped_fn(*args):  # pylint: disable=missing-docstring
# --> 231         ret = wrapper_helper(*args)
#     232         ret = structure.to_tensor_list(self._output_structure, ret)
#     233         return [ops.convert_to_tensor(t) for t in ret]
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py in wrapper_helper(*args)
#     159       if not _should_unpack(nested_args):
#     160         nested_args = (nested_args,)
# --> 161       ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#     162       ret = variable_utils.convert_variables_to_tensors(ret)
#     163       if _should_pack(ret):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     691       except Exception as e:  # pylint:disable=broad-except
#     692         if hasattr(e, 'ag_error_metadata'):
# --> 693           raise e.ag_error_metadata.to_exception(e)
#     694         else:
#     695           raise
#
# OperatorNotAllowedInGraphError: in user code:
#
#     File "<ipython-input-17-da79428a88dd>", line 20, in None  *
#         lambda x, y: load_image_and_labels(x, y, max_labels)
#     File "<ipython-input-17-da79428a88dd>", line 12, in load_image_and_labels  *
#         labels = tf.ragged.constant([tf.strings.to_number(label, tf.float32) for label in labels if tf.strings.length(label) > 0])
#
#     OperatorNotAllowedInGraphError: Using a symbolic `tf.Tensor` as a Python `bool` is not allowed. You can attempt the following resolutions to the problem: If you are running in Graph mode, use Eager execution mode or decorate this function with @tf.function. If you are using AutoGraph, you can try decorating this function with @tf.function. If that does not work, then you may be using an unsupported feature or your source code may not be visible to AutoGraph. See https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/autograph/g3doc/reference/limitations.md#access-to-source-code for more information.

# %%
def yolo_loss(y_true, y_pred):
    # Implement the loss function here
    # This is just a placeholder function
    return tf.reduce_sum((y_true - y_pred) ** 2)

# %%
optimizer = tf.optimizers.Adam(learning_rate=0.001)
epochs = 10

for epoch in range(epochs):
    print("\nStart of epoch %d" % (epoch,))
    for step, (x_batch_train, y_batch_train) in enumerate(train_dataset):
        with tf.GradientTape() as tape:
            reconstructed = model(x_batch_train, training=True)  # Logits for this minibatch
            # Compute the loss value for this minibatch
            loss_value = yolo_loss(y_batch_train, reconstructed)

        grads = tape.gradient(loss_value, model.trainable_weights)
        optimizer.apply_gradients(zip(grads, model.trainable_weights))

        # Log every 100 batches.
        if step % 100 == 0:
            print("Training loss (for one batch) at step %d: %.4f" % (step, float(loss_value)))
            print("Seen so far: %d samples" % ((step + 1) * batch_size))
# Out:
# Start of epoch 0
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-7-6339d3a92c84> in <cell line: 4>()
#       4 for epoch in range(epochs):
#       5     print("\nStart of epoch %d" % (epoch,))
# ----> 6     for step, (x_batch_train, y_batch_train) in enumerate(train_dataset):
#       7         with tf.GradientTape() as tape:
#       8             reconstructed = model(x_batch_train, training=True)  # Logits for this minibatch
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __next__(self)
#     808   def __next__(self):
#     809     try:
# --> 810       return self._next_internal()
#     811     except errors.OutOfRangeError:
#     812       raise StopIteration
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _next_internal(self)
#     771     # to communicate that there is no more data to iterate over.
#     772     with context.execution_mode(context.SYNC):
# --> 773       ret = gen_dataset_ops.iterator_get_next(
#     774           self._iterator_resource,
#     775           output_types=self._flat_output_types,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in iterator_get_next(iterator, output_types, output_shapes, name)
#    3027       return _result
#    3028     except _core._NotOkStatusException as e:
# -> 3029       _ops.raise_from_not_ok_status(e, name)
#    3030     except _core._FallbackException:
#    3031       pass
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    5881 def raise_from_not_ok_status(e, name) -> NoReturn:
#    5882   e.message += (" name: " + str(name if name is not None else ""))
# -> 5883   raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#    5884
#    5885
#
# InvalidArgumentError: {{function_node __wrapped__IteratorGetNext_output_types_2_device_/job:localhost/replica:0/task:0/device:CPU:0}} Cannot batch tensors with different shapes in component 1. First element had shape [20] and element 1 had shape [15]. [Op:IteratorGetNext] name:
